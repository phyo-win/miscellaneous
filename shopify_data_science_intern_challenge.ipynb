# %%
import pandas as pd

from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
sh = gc.create('My cool spreadsheet')
worksheet = gc.open('My cool spreadsheet').sheet1
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-8-7980df9ffecf> in <module>()
# ----> 1 sh = gc.create('My cool spreadsheet')
#       2 worksheet = gc.open('My cool spreadsheet').sheet1
#
# /usr/local/lib/python3.7/dist-packages/gspread/client.py in create(self, title)
#     214             'post',
#     215             DRIVE_FILES_API_V3_URL,
# --> 216             json=payload
#     217         )
#     218         spreadsheet_id = r.json()['id']
#
# /usr/local/lib/python3.7/dist-packages/gspread/client.py in request(self, method, endpoint, params, data, json, files, headers)
#      71             return response
#      72         else:
# ---> 73             raise APIError(response)
#      74
#      75     def list_spreadsheet_files(self, title=None):
#
# ...

# %%
worksheet = gc.open('2019 Winter Data Science Intern Challenge Data Set - Sheet1').sheet1
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/gspread/client.py in open(self, title)
#     121                 lambda x: x['name'] == title,
# --> 122                 self.list_spreadsheet_files(title)
#     123             )
#
# /usr/local/lib/python3.7/dist-packages/gspread/utils.py in finditem(func, seq)
#      93     """
# ---> 94     return next((item for item in seq if func(item)))
#      95
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# SpreadsheetNotFound                       Traceback (most recent call last)
# <ipython-input-7-983d513981e7> in <module>()
# ----> 1 worksheet = gc.open('2019 Winter Data Science Intern Challenge Data Set - Sheet1').sheet1
#
# /usr/local/lib/python3.7/dist-packages/gspread/client.py in open(self, title)
# ...

# %%
path = '/content/drive/MyDrive/2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv'
#"C:\Users\Phyo Win\Downloads\2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv"

# %%
df = pd.read_csv('/content/drive/MyDrive/2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-0ef52ed9e14f> in <module>()
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Career/Companies/Shopify/intern_challenge_datset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-5d078fbb6d2c> in <module>()
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/Career/Companies/Shopify/intern_challenge_datset.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Citibike/202101-citibike-tripdata.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d5b5b96f4e51> in <module>()
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/Citibike/202101-citibike-tripdata.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...
